# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interactive
from IPython.display import display
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec
from sklearn import neighbors
from sklearn.metrics import roc_curve, auc

from simulate import simulate_samples
# %load_ext autoreload
# %autoreload 2

# %%
# Define default values for sliders
default_values = {
    "n_cells": 10000,
    "frac_leukemic_AML1": 0.1,
    "frac_leukemic_AML2": 0.01,
    "frac_leukemic_AML3": 0.1,
    "mean_healthy_x": -1,
    "std_healthy_x": 0.5,
    "mean_healthy_y": -1,
    "std_healthy_y": 0.5,
    "dist_healthy_LAIP1": 3,
    "std_LAIP1_x": 0.5,
    "std_LAIP1_y": 0.5,
    "dist_healthy_LAIP2": 3,
    "std_LAIP2_x": 0.5,
    "std_LAIP2_y": 0.5
}

# Call the simulate_samples function with unpacked values from the default_values dictionary
NBM, AML1, AML2, AML3 = simulate_samples(**default_values)

# %%
from plots import plot_cluster_with_normal

# %%
plot_cluster_with_normal(**default_values)
# Out:
# /media/timmocking/HDD/repositories/cMRD-review/plots.py:182: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax.set_ylim(0, 1.05)
# /media/timmocking/HDD/repositories/cMRD-review/plots.py:182: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax.set_ylim(0, 1.05)
# /media/timmocking/HDD/repositories/cMRD-review/plots.py:182: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax.set_ylim(0, 1.05)
